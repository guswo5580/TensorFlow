# %%
import tensorflow as tf

# %%
x_train = [1, 2, 3]
y_train = [1, 2, 3]

# %%
# 새로운 변수를 선언 W, b
W = tf.Variable(tf.random_normal([1]), name = "weight")
b = tf.Variable(tf.random_normal([1]), name = "bias")

# %%
# 기본 H(x) 공식 적용
hypo = x_train * W + b

# %%
cost = tf.reduce_mean(tf.square(hypo - y_train))

# %%
# cost 최소화를 위한 gradient 방식 적용
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
# Learning 을 위한 준비
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001) :
    sess.run(train)
    if step % 20 == 0 :
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 1.2839837 [0.31463686] [0.38541654]
# 20 0.05436781 [0.7175673] [0.5303841]
# 40 0.039297614 [0.7661404] [0.5209864]
# 60 0.035599303 [0.7804921] [0.4979806]
# 80 0.032331053 [0.7911283] [0.47471815]
# 100 0.02936356 [0.8009749] [0.45242158]
# 120 0.026668483 [0.8103313] [0.43116072]
# 140 0.024220733 [0.8192453] [0.4108979]
# 160 0.021997651 [0.82774013] [0.39158717]
# 180 0.019978615 [0.8358357] [0.37318403]
# 200 0.018144911 [0.84355086] [0.35564578]
# 220 0.016479485 [0.85090333] [0.3389317]
# 240 0.0149669275 [0.8579103] [0.3230032]
# 260 0.013593212 [0.864588] [0.3078232]
# 280 0.012345575 [0.8709519] [0.29335666]
# 300 0.011212447 [0.87701666] [0.27956992]
# 320 0.010183324 [0.88279647] [0.2664311]
# 340 0.009248663 [0.88830465] [0.25390986]
# 360 0.008399778 [0.8935539] [0.24197698]
# 380 0.0076288185 [0.8985565] [0.230605]
# 400 0.0069286153 [0.9033239] [0.21976744]
# 420 0.006292676 [0.9078674] [0.20943914]
# 440 0.005715095 [0.91219723] [0.19959629]
# 460 0.0051905517 [0.9163236] [0.19021602]
# 480 0.0047141425 [0.92025614] [0.18127657]
# 500 0.0042814645 [0.9240038] [0.17275725]
# 520 0.0038884983 [0.9275753] [0.16463831]
# 540 0.0035315973 [0.93097895] [0.15690096]
# 560 0.003207447 [0.9342227] [0.14952722]
# 580 0.0029130622 [0.937314] [0.1425]
# 600 0.0026456874 [0.94026] [0.13580307]
# 620 0.002402854 [0.94306755] [0.12942082]
# 640 0.002182313 [0.94574314] [0.12333851]
# 660 0.001982012 [0.94829303] [0.11754209]
# 680 0.0018000997 [0.95072305] [0.11201806]
# 700 0.001634874 [0.95303893] [0.10675363]
# 720 0.0014848263 [0.95524585] [0.10173661]
# 740 0.0013485384 [0.9573491] [0.09695538]
# 760 0.0012247665 [0.95935345] [0.09239888]
# 780 0.0011123513 [0.96126384] [0.08805647]
# 800 0.0010102558 [0.9630843] [0.08391812]
# 820 0.0009175311 [0.96481913] [0.0799743]
# 840 0.00083331997 [0.9664725] [0.07621581]
# 860 0.0007568293 [0.9680482] [0.07263395]
# 880 0.00068736327 [0.9695498] [0.06922044]
# 900 0.0006242765 [0.9709809] [0.06596735]
# 920 0.00056697597 [0.9723447] [0.0628671]
# 940 0.0005149346 [0.9736444] [0.05991256]
# 960 0.00046767513 [0.97488296] [0.05709688]
# 980 0.00042474896 [0.9760634] [0.05441354]
# 1000 0.00038576694 [0.9771883] [0.0518563]
# 1020 0.00035036015 [0.9782604] [0.04941926]
# 1040 0.00031820018 [0.97928214] [0.04709673]
# 1060 0.00028899318 [0.98025584] [0.04488331]
# 1080 0.00026246815 [0.98118365] [0.04277395]
# 1100 0.00023837911 [0.98206794] [0.04076374]
# 1120 0.00021649948 [0.9829107] [0.038848]
# 1140 0.00019662821 [0.9837138] [0.03702229]
# 1160 0.00017858147 [0.98447925] [0.03528238]
# 1180 0.00016218873 [0.98520863] [0.03362422]
# 1200 0.0001473035 [0.9859038] [0.032044]
# 1220 0.00013378302 [0.98656625] [0.03053805]
# 1240 0.00012150483 [0.98719764] [0.02910287]
# 1260 0.00011035148 [0.9877992] [0.02773514]
# 1280 0.000100223035 [0.9883726] [0.02643173]
# 1300 9.102446e-05 [0.988919] [0.02518954]
# 1320 8.2671155e-05 [0.9894397] [0.02400577]
# 1340 7.508327e-05 [0.98993623] [0.02287757]
# 1360 6.8190064e-05 [0.9904092] [0.02180235]
# 1380 6.1932406e-05 [0.99085987] [0.02077766]
# 1400 5.624745e-05 [0.99128944] [0.01980118]
# 1420 5.108476e-05 [0.99169874] [0.01887061]
# 1440 4.639596e-05 [0.9920889] [0.01798378]
# 1460 4.213731e-05 [0.9924607] [0.01713862]
# 1480 3.82701e-05 [0.9928151] [0.01633314]
# 1500 3.4757122e-05 [0.99315274] [0.0155655]
# 1520 3.1567146e-05 [0.99347454] [0.01483398]
# 1540 2.8669912e-05 [0.99378115] [0.01413684]
# 1560 2.6038122e-05 [0.9940734] [0.01347248]
# 1580 2.3648778e-05 [0.9943519] [0.01283934]
# 1600 2.1478363e-05 [0.9946174] [0.01223595]
# 1620 1.9506728e-05 [0.9948703] [0.0116609]
# 1640 1.7716366e-05 [0.99511147] [0.01111289]
# 1660 1.6090447e-05 [0.99534124] [0.01059059]
# 1680 1.4613459e-05 [0.9955601] [0.01009285]
# 1700 1.3271999e-05 [0.9957688] [0.00961853]
# 1720 1.2053838e-05 [0.9959676] [0.00916649]
# 1740 1.0947389e-05 [0.99615717] [0.00873568]
# 1760 9.942777e-06 [0.9963378] [0.00832513]
# 1780 9.030184e-06 [0.99650985] [0.00793387]
# 1800 8.201313e-06 [0.9966739] [0.00756102]
# 1820 7.4482537e-06 [0.9968302] [0.00720566]
# 1840 6.764984e-06 [0.9969792] [0.006867]
# 1860 6.143711e-06 [0.99712116] [0.00654427]
# 1880 5.5796804e-06 [0.9972564] [0.00623673]
# 1900 5.067861e-06 [0.9973853] [0.00594365]
# 1920 4.602672e-06 [0.9975082] [0.00566434]
# 1940 4.1804055e-06 [0.99762535] [0.00539813]
# 1960 3.7967457e-06 [0.99773693] [0.00514443]
# 1980 3.4482975e-06 [0.99784327] [0.00490268]
# 2000 3.131482e-06 [0.99794465] [0.00467227]
